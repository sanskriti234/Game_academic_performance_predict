# %% [markdown]
# <a href="https://colab.research.google.com/github/sanskriti234/Game_academic_performance_predict/blob/main/load.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pickle
import pandas as pd

# %%
pipe=pickle.load(open('pipe.pkl','rb'))

# %%
student_id = int(input("Student ID: "))
age = int(input("Age: "))
gender = input("Gender (Male/Female): ")
gaming_hours = float(input("Gaming Hours: "))
study_hours = float(input("Study Hours: "))
sleep_hours = float(input("Sleep Hours: "))
attendance = float(input("Attendance: "))
gaming_genre = input("Gaming Genre: ")
social_activity = float(input("Social Activity Hours: "))
device_usage = float(input("Device Usage Hours: "))
reaction_time_ms = float(input("Reaction Time (ms): "))
addiction_score = float(input("Addiction Score: "))
stress_level = input("Stress Level (Low/Medium/High): ")
# Out:
# Student ID: 27
# Age: 19
# Gender (Male/Female): Female
# Gaming Hours: 2.15
# Study Hours: 4.56
# Sleep Hours: 6.73
# Attendance: 63.7
# Gaming Genre: FPS
# Social Activity Hours: 1.86
# Device Usage Hours: 6.82
# Reaction Time (ms): 282.04
# Addiction Score: 3.66
# Stress Level (Low/Medium/High): Medium

# %%
data = pd.DataFrame({ 'student_id':[student_id],
                      'age':[age], 'gender':[gender],
                      'gaming_hours':[gaming_hours],
                      'study_hours':[study_hours],
                      'sleep_hours':[sleep_hours],
                      'attendance':[attendance],
                      'gaming_genre':[gaming_genre],
                      'social_activity':[social_activity],
                      'device_usage':[device_usage],
                      'reaction_time_ms':[reaction_time_ms],
                      'addiction_score':[addiction_score],
                      'stress_level':[stress_level] })

# %%
prediction = pipe.predict(data)
print(f"\nPredicted Grade: {prediction[0]:.2f}")
# Out:
# Predicted Grade: 67.06
